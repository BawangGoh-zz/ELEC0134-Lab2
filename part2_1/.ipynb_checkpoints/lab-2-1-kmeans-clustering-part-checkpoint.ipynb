# %% [markdown]
# #  Day 2: Clustering and Dimensionality Reduction
# ## K-Means & Principal Components Analysis (PCA)

# %% [markdown]
# In this notebook we are going to implement clustering with and without dimensionality reduction. In particular, you will:
#
# * Complete a function `kmeansNewPredict(X, k)` to implement k-means algorithm from scratch for different number of clusters k=2,3,4,5.
# * Use the function `PCA()` from scikit-learn in order to reduce the dimension of data to d = 2. Plot the data.

# %% [markdown]
# # Import libraries

# %% [markdown]
# The required libraries for this notebook are pandas, sklearn, copy, numpy, pickle, mpl_toolkits and matplotlib.

# %%
# import libraries
import pickle
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# # Load the data
# For the clustering tasks we will use the dataset clustering_data.pkl. It consists of 3000 data points. Each data point has 2 features (2D data). The data points come from different distributions (between 2 and 5).

# %%
# Loading the pickle file
data_file = open('./dataset/clustering_data.pkl','rb')
data = pickle.load(data_file, encoding='latin1')
data_file.close()
X = data['X']

# %%
print(X)
# Out:
# [[ 6.69706182  3.06652895]
#  [ 7.02434089  2.77288835]
#  [ 4.606128    7.72383249]
#  [ 4.15038052  9.44456707]
#  [-4.0101222   7.11349396]
#  [-4.39910985  8.35112405]
#  [-4.41838226  5.21884235]
#  [-5.32873984  7.7032802 ]
#  [ 2.2227981   2.73263708]
#  [ 5.5284292   4.07146546]
#  [ 8.4177602   3.55107524]
#  [-5.93055675  7.99847848]
#  [-4.91521409  7.8768832 ]
#  [ 4.92924207  8.47694447]
#  [ 4.61061749  4.12121972]
#  [-5.68116744  7.05459454]
#  [ 5.9808943   2.16835881]
#  [ 3.92387787  1.6944995 ]
#  [ 3.51468126  0.88189154]
#  [-6.88075256  6.82219473]
#  [-5.97233972  7.91352821]
#  [ 2.4998847   2.2728462 ]
#  [ 4.49467026 10.20174698]
#  [ 8.25026273  2.70506655]
#  [ 3.43839863  7.94826422]
#  [-5.28659567  8.62110212]
#  [-6.63389141  7.87335604]
#  [-6.26087514  6.95792145]
#  [ 5.41918997  3.06729923]
#  [ 2.37400371  2.4435768 ]
#  [ 1.55975963  1.68443507]
#  [ 7.42226886  1.34645418]
#  [ 6.22838714  4.16335487]
#  [ 3.4467557   8.15995354]
#  [ 2.66430673  9.96700643]
#  [ 2.66909167  0.37700167]
#  [-5.31600203  6.61782583]
#  [-3.25057743  7.5105195 ]
#  [ 2.44275501  0.28791316]
#  [ 2.94111058  0.37710144]
#  [ 2.99055239 11.56259595]
#  [ 5.06894582  9.06808233]
#  [ 4.42934666  8.82316959]
#  [ 6.4202262   4.20744267]
#  [ 3.44346708  1.96756239]
#  [-6.36690691  5.5017717 ]
#  [ 4.69131079  9.45875688]
#  [ 3.08225228 -0.87105149]
#  [ 4.15509178  1.59010384]
#  [ 7.03438663  3.77281285]
#  [ 4.71897898  9.46702077]
#  [ 3.28863783  1.64765305]
#  [ 5.30942233  8.37337497]
#  [ 6.58342925  1.80172903]
#  [-4.31667925  8.31908335]
#  [-6.24449129  6.20426884]
#  [-6.7756642   8.13531373]
#  [ 4.37913384  7.31164689]
#  [ 3.50328891 11.93400768]
#  [ 6.01665325  2.81667062]
#  [ 6.86792635  4.70434676]
#  [ 3.4862591  10.17012004]
#  [ 5.84878115  9.04582887]
#  [ 3.31866031 10.33567162]
#  [ 5.71323455  4.86931911]
#  [ 2.17217178 10.04995677]
#  [-7.35145825  8.61573852]
#  [ 2.17353562  1.7492324 ]
#  [ 2.37896682  9.46200673]
#  [-3.32287084  6.66262857]
#  [ 6.37134606  4.14029223]
#  [-5.94913947  6.49660018]
#  [ 4.57342372  2.78029458]
#  [ 6.44074344  2.74405932]
#  [-4.22879762  6.59600601]
#  [ 3.22107621  9.23061522]
#  [ 7.29139822  2.66882335]
#  [-6.95131581  4.95682009]
#  [ 2.868181    1.07512315]
#  [ 5.35129855  1.98461363]
#  [-6.48049294  8.02330267]
#  [-6.26376457  6.2969208 ]
#  [ 3.59846672  6.51022479]
#  [ 7.4866454   3.54574953]
#  [ 6.80801196  2.95783056]
#  [ 3.81197757 10.59376989]
#  [ 2.81376526  2.4263855 ]
#  [-6.32295941  8.30716691]
#  [-4.55593139  6.0237467 ]
#  [-5.33021253  6.68202641]
#  [ 3.69701914  4.72008745]
#  [ 2.53922326  1.22803914]
#  [ 5.66109653 10.2587569 ]
#  [ 2.99682851  9.66953025]
#  [ 2.69736854  2.76788746]
#  [ 4.12536924  8.93263911]
#  [ 4.15716622  1.29795398]
#  [ 3.00292586 11.0332789 ]
#  [-6.31439004  7.62954091]
#  [-6.21118037  6.27107254]
#  [ 7.25566744  7.96962394]
#  [ 3.73236121  9.72251909]
#  [ 4.1713253  10.32303911]
#  [ 5.62146992  1.17971741]
#  [ 7.04756666  2.70636651]
#  [ 3.68807744  9.30237328]
#  [ 7.38603719  3.79781902]
#  [-6.54089969  7.29638662]
#  [ 7.05186772  1.3765632 ]
#  [-6.05510837  5.68103141]
#  [-4.75355681  8.11559218]
#  [ 4.87588079  2.85942075]
#  [-5.58493716  7.03240347]
#  [ 5.50094935  3.15693797]
#  [ 6.10594957  3.41193836]
#  [-6.66722827  7.33491514]
#  [ 4.52831808 11.85387598]
#  [ 5.88663247  4.22402402]
#  [ 4.5720607   4.92221536]
#  [ 2.35329629  0.60172753]
#  [ 4.42075517 10.15848487]
#  [ 4.29346612 11.19319899]
#  [ 5.22697197  1.80928544]
#  [ 7.31450899  4.59700413]
#  [ 6.18129437  3.73805491]
#  [ 3.11072196 10.71357302]
#  [ 6.32548762  3.17000763]
#  [ 5.86812296  6.12043685]
#  [ 3.4606354   1.86099088]
#  [ 4.52253066  8.56671929]
#  [ 5.00584429  5.07228074]
#  [ 2.06452677  1.48148204]
#  [ 6.24268371  3.25088612]
#  [ 5.90463575  8.83836835]
#  [ 4.49948905  0.93163244]
#  [ 4.43727393  2.30722019]
#  [ 3.3600203   9.02178693]]

# %% [markdown]
# # Use K-means clustering from a library

# %% [markdown]
# We will first see how k-means can be implemented using already available functions from the scikit-learn library.

# %%
# sklearn functions implementation
def kmeansPredict(X, k):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    y_kmeans = kmeans.predict(X)
    return y_kmeans, kmeans.cluster_centers_

# run K-means for different values of k
k1 = 2
y_predict, centers = kmeansPredict(X,k1)
#  plot the clusters 
plt.scatter(X[:, 0], X[:, 1], c=y_predict, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
print(centers)
# Out:
# [[ 4.50943913  4.75485326]
#  [-5.54239156  7.26958711]]

# %% [markdown]
# # Implement you own K-means clustering function

# %% [markdown]
# You are asked to calculate the missing variables in the `kmeansNewPredict(X,k)` function.

# %%
# Euclidean Distance Caculator
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

def kmeansNewPredict(X,k):
    # Generate X and Y coordinates of random centroids
    C_x = np.random.randint(0, np.max(X), size=k)
    C_y = np.random.randint(0, np.max(X), size=k)
    C = np.array(list(zip(C_x, C_y)), dtype=np.float32)
    
    #  To store the value of centroids when it updates
    C_old = np.zeros(C.shape)
    
    # Cluster labels (0,1,2)
    clusters = np.zeros(len(X))
    
    # Error: Distance between new centroids and old centroids
    error = dist(C, C_old, None)
    
    # Loop will run till the error becomes zero
    while error != 0:
        # Assigning each value to its closest cluster
        for i in range(len(X)):
            distances = dist(X[i], C)
            #cluster = ...
            cluster = np.argmin(distances)
            clusters[i] = cluster
        
        # Storing the old centroid values
        C_old = deepcopy(C)
        
        # Finding the new centroids by taking the average value
        for i in range(k):
            #points = ...
            points = [X[j] for j in range(len(X)) if clusters[j] == i]
            #C[i] = ...
            C[i] = np.mean(points, axis = 0)
        error = dist(C, C_old, None)

    return points, C

# run K-means for different values of k
k2 = 2
y_kmeans1, centers1 = kmeansNewPredict(X,k2)

#  plot the clusters 
fig, ax = plt.subplots()
for i in range(k2):
        y_kmeans1 = np.array([X[j] for j in range(len(X))])
        ax.scatter(y_kmeans1[:, 0], y_kmeans1[:, 1], s=50)
ax.scatter(centers1[:, 0], centers1[:, 1],  c='black', s=200, alpha=0.5);

print(centers1)
# Out:
# [[ 4.509439   4.7548532]
#  [-5.542392   7.269587 ]]

# %% [markdown]
# # Load the iris dataset for PCA

# %% [markdown]
# We will now use the iris dataset available from scikit learn library, which includes 4 feature columns (sepal length, sepal width, petal length, and petal width) and 150 data points.

# %%
dataset=load_iris()

#print(dataset.data.shape) # shape of data
#print(dataset.target.shape)
#print(boston.feature_names)
dataset_df=pd.DataFrame(dataset.data,columns=dataset.feature_names) # convert the boston.data to a a dataframe
print(dataset_df.head())

X_iris=dataset.data
y_iris=dataset.target

print(X_iris.shape)
print(y_iris.shape)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# (150, 4)
# (150,)
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False]
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False]

# %%
# to enable graph interactivity 
# %matplotlib notebook  
fig_pca=plt.figure(1, figsize=(4,3))
plot=Axes3D(fig_pca, rect=[0,0,.95,1],elev=48, azim=134)


for name, label in [('Setosa',0), ('Versicolour',1), ('Virginica',2)]:
    plot.text3D(X_iris[y_iris==label,0].mean(),
                X_iris[y_iris==label,1].mean()+1.5,
                X_iris[y_iris==label,2].mean(),name, 
                horizontalalignment='center',
                bbox=dict(alpha=.5, edgecolor='w',facecolor='w') )


y_iris=y_iris.astype(np.float)    



plot.scatter(X_iris[:, 0], X_iris[:, 1], X_iris[:, 2], c=y_iris,  cmap=plt.cm.nipy_spectral, edgecolor='k')
# Out:
# <img src="data:image/png;base64,..." width="400">
# Virginica

# %% [markdown]
# # Scale your data
#
# Before we apply PCA, the data features (i.e. X) should be scaled (standardized) onto unit scale (mean = 0 and variance = 1). You could do so by using `StandardScaler()` function from scikit-learn.
#
# For more information on the importance of feature scaling, please visit: **https://scikit-learn.org/stable/auto_examples/preprocessing/plot_scaling_importance.html#sphx-glr-auto-examples-preprocessing-plot-scaling-importance-py**

# %%
# Call the function
sc = StandardScaler() 
# Standardizing the features
X_scale = sc.fit_transform(X_iris)  
print(X_scale.shape)
# Out:
# (150, 4)

# %% [markdown]
# # Project data to 2D using PCA
#
# In the following cell you should implement the projection of the original data into 2 dimensions. Then apply kmeans and compare your results with and without PCA.
#
# **Note 1:** The original data is 4 dimensional.
#
# **Note 2:** The principal components you will create with dimensionality reduction, don't have a particular meaning assigned (usually). They are just the two main dimensions of variation.

# %%
#pca = ... #call PCA
pca = PCA(n_components=2)
#X_new = ... # fit
X_new = pca.fit_transform(X_scale)

# Principle component information capture
print('Information included per principal component (%): '+str(pca.explained_variance_ratio_*100))
# Out:
# Information included per principal component (%): [72.96244541 22.85076179]

# %%
# Number of centroids for 3 different flowers
k = 3

# K-means with PCA
y_new, centers_new = kmeansPredict(X_new,k)
print(centers_new)

# K-means without PCA
y_no_PCA, centers_no_PCA = kmeansPredict(X_scale,k)
print(centers_no_PCA)
# Out:
# [[ 1.71731904  0.65486305]
#  [-2.22475316  0.28892745]
#  [ 0.61742366 -0.79845836]]
# [[ 1.13597027  0.08842168  0.99615451  1.01752612]
#  [-1.01457897  0.85326268 -1.30498732 -1.25489349]
#  [-0.05021989 -0.88337647  0.34773781  0.2815273 ]]

# %%
# Visualization of 2D projection
fig = plt.figure(2, figsize=(5,5))
ax = fig.add_subplot(1,1,1)
ax.set_xlabel('Principal Component 1', fontsize = 10)
ax.set_ylabel('Principal Component 2', fontsize = 10)
ax.set_title('2 component PCA', fontsize = 15)

targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for name, label in [('Setosa',0), ('Versicolour',1), ('Virginica',2)]:
    ax.scatter(X_new[y_iris == label,0]
               , X_new[y_iris == label,1]
               , c = colors[label]
               , s = 50)
ax.legend(targets)
ax.grid()
# Out:
# <img src="data:image/png;base64,..." width="500">
